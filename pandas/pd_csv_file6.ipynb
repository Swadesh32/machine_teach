# %% [markdown]
# # pandas interpolate

# %%
#pandas interpolate ()function is basically used to fill Nan values to fill Nan values  in data frame or series .

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:\\Users\\maury\\Desktop\\csv\\Book5.csv')
df1
# Out:
#    st_id  st_id.1  st_id.2 st_id.3  st_id.4  st_id.5 data
# 0   11O1        1      2.0       A        3        1  yes
# 1   1102        1      3.0       S        5        2  NaN
# 2   1103        1      NaN       D       65        3  NaN
# 3   1104        2      NaN       F        7        4  NaN
# 4   1105        3      NaN       G       98        5  NaN
# 5    990        9      NaN       m       98        9  NaN
# 6   11O1        1      2.0       A        3        1   no
# 7   1102        1      3.0       S        5        2   no
# 8   1103        1      4.0       D       65        3  yes
# 9   1104        2      5.0       F        7        4  yes
# 10  1105        3      1.0       G       98        5   no

# %%
df1.interpolate()
# Out:
#    st_id  st_id.1  st_id.2 st_id.3  st_id.4  st_id.5 data
# 0   11O1        1      2.0       A        3        1  yes
# 1   1102        1      3.0       S        5        2  NaN
# 2   1103        1      2.8       D       65        3  NaN
# 3   1104        2      2.6       F        7        4  NaN
# 4   1105        3      2.4       G       98        5  NaN
# 5    990        9      2.2       m       98        9  NaN
# 6   11O1        1      2.0       A        3        1   no
# 7   1102        1      3.0       S        5        2   no
# 8   1103        1      4.0       D       65        3  yes
# 9   1104        2      5.0       F        7        4  yes
# 10  1105        3      1.0       G       98        5   no

# %%
df1.interpolate(mathod = 'linear')
# Out:
#    st_id  st_id.1  st_id.2 st_id.3  st_id.4  st_id.5 data
# 0   11O1        1      2.0       A        3        1  yes
# 1   1102        1      3.0       S        5        2  NaN
# 2   1103        1      2.8       D       65        3  NaN
# 3   1104        2      2.6       F        7        4  NaN
# 4   1105        3      2.4       G       98        5  NaN
# 5    990        9      2.2       m       98        9  NaN
# 6   11O1        1      2.0       A        3        1   no
# 7   1102        1      3.0       S        5        2   no
# 8   1103        1      4.0       D       65        3  yes
# 9   1104        2      5.0       F        7        4  yes
# 10  1105        3      1.0       G       98        5   no

# %%
df2 = pd.read_csv('C:\\Users\\maury\\Desktop\\csv\\date.csv')
df2
# Out:
#         1      2        3       4     5 Unnamed: 5  Unnamed: 6
# 0   st_id  CLASS  STUDY_H  SCHOOL  M_NO    PERSENT       date
# 1    11O1      1        2       A     3          1  27-08-2023
# 2    1102      1        3       S     5          2         NaN
# 3    1103      1        4       D    65          3  27-08-2023
# 4    1104      2        5       F     7          4  27-08-2023
# 5    1105      3        1       G    98          5  27-08-2023
# 6     990      9        0       m    98          9  27-08-2023
# 7    11O1      1        2       A     3          1  27-08-2023
# 8    1102      1        3       S     5          2  27-08-2023
# 9    1103      1        4       D    65          3  27-08-2023
# 10   1104      2        5       F     7          4  27-08-2023
# 11   1105      3        1       G    98          5  27-08-2023

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 type(df2.date)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'date'
